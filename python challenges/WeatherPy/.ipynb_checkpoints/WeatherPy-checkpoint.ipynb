# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
# Import API key
from config import api_key
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

#set the temp_units
temp_units = "imperial"

# define url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={api_key}&units={temp_units}&q="

# List for holding lat_lngs and cities
lat_lngs = []
#Generate Cities List
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs =zip(lats, lngs)

# %%
# Identify nearest city for each lat, lng combination

for lat,lng in lat_lngs:
    city = citipy.nearest_city(lat, lng).city_name
    
# If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count      
len(cities)
# Out:
# 763

# %%
# Perform API Calls
url = "http://api.openweathermap.org/data/2.5/weather?"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={temp_units}&q="

# %%
# Perform a weather check on each city using a series of successive API calls. Include a print log of each city as it'sbeing processed (with the city number and city name).
for city in cities:
    response = requests.get(query_url + city).json()

# %%
# set lists for the datafrzame

city_two = []
cloudiness = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns

for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudiness.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | bambanglipuro
# Processing Record 2 of Set 1 | anloga
# Processing Record 3 of Set 1 | sao filipe
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | biloela
# Processing Record 9 of Set 1 | emerald
# Processing Record 10 of Set 1 | grand gaube
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | sandusky
# Processing Record 14 of Set 1 | padang
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | lazaro cardenas
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | nanortalik
# City not found. Skipping...
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | nikolskoye
# Processing Record 24 of Set 1 | isiro
# Processing Record 25 of Set 1 | cidreira
# Processing Record 26 of Set 1 | vanavara
# Processing Record 27 of Set 1 | nenjiang
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | thompson
# Processing Record 31 of Set 1 | san pedro
# Processing Record 32 of Set 1 | ranot
# Processing Record 33 of Set 1 | khatanga
# Processing Record 34 of Set 1 | shitanjing
# Processing Record 35 of Set 1 | hithadhoo
# Processing Record 36 of Set 1 | leningradskiy
# Processing Record 37 of Set 1 | kajaani
# Processing Record 38 of Set 1 | torbay
# Processing Record 39 of Set 1 | rio gallegos
# Processing Record 40 of Set 1 | airai
# Processing Record 41 of Set 1 | anupshahr
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | avarua
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | port shepstone
# Processing Record 48 of Set 1 | kokopo
# Processing Record 49 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 1 of Set 2 | constitucion
# Processing Record 2 of Set 2 | kruisfontein
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | grand river south east
# Processing Record 5 of Set 2 | ahipara
# Processing Record 6 of Set 2 | grindavik
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | katsuura
# Processing Record 9 of Set 2 | sao joao da barra
# Processing Record 10 of Set 2 | acari
# City not found. Skipping...
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | hamilton
# Processing Record 13 of Set 2 | port hardy
# Processing Record 14 of Set 2 | sabha
# Processing Record 15 of Set 2 | verkhnevilyuysk
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | coihaique
# Processing Record 18 of Set 2 | ararat
# Processing Record 19 of Set 2 | qaanaaq
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | chaumont
# City not found. Skipping...
# Processing Record 22 of Set 2 | north bend
# Processing Record 23 of Set 2 | bow island
# Processing Record 24 of Set 2 | ilulissat
# Processing Record 25 of Set 2 | cherskiy
# Processing Record 26 of Set 2 | gunzenhausen
# Processing Record 27 of Set 2 | murgab
# Processing Record 28 of Set 2 | nara
# Processing Record 29 of Set 2 | haines junction
# Processing Record 30 of Set 2 | sao raimundo nonato
# Processing Record 31 of Set 2 | gravdal
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | santa branca
# Processing Record 34 of Set 2 | meridian
# Processing Record 35 of Set 2 | berlevag
# Processing Record 36 of Set 2 | geraldton
# Processing Record 37 of Set 2 | tiksi
# Processing Record 38 of Set 2 | hermanus
# Processing Record 39 of Set 2 | verkhoyansk
# Processing Record 40 of Set 2 | dumai
# Processing Record 41 of Set 2 | matara
# City not found. Skipping...
# Processing Record 42 of Set 2 | flinders
# Processing Record 43 of Set 2 | sibolga
# Processing Record 44 of Set 2 | karratha
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 2 | buala
# Processing Record 46 of Set 2 | champerico
# Processing Record 47 of Set 2 | tandil
# Processing Record 48 of Set 2 | vila velha
# Processing Record 49 of Set 2 | sembe
# Processing Record 1 of Set 3 | ketchikan
# Processing Record 2 of Set 3 | amta
# Processing Record 3 of Set 3 | meulaboh
# Processing Record 4 of Set 3 | betera
# Processing Record 5 of Set 3 | pedernales
# Processing Record 6 of Set 3 | tahe
# Processing Record 7 of Set 3 | narsaq
# Processing Record 8 of Set 3 | castanos
# Processing Record 9 of Set 3 | qasigiannguit
# Processing Record 10 of Set 3 | lae
# Processing Record 11 of Set 3 | elbistan
# Processing Record 12 of Set 3 | upernavik
# Processing Record 13 of Set 3 | zyryanovsk
# Processing Record 14 of Set 3 | carnarvon
# Processing Record 15 of Set 3 | muli
# Processing Record 16 of Set 3 | adrar
# Processing Record 17 of Set 3 | moba
# Processing Record 18 of Set 3 | barrow
# Processing Record 19 of Set 3 | davila
# Processing Record 20 of Set 3 | new norfolk
# City not found. Skipping...
# Processing Record 21 of Set 3 | antofagasta
# Processing Record 22 of Set 3 | lebu
# Processing Record 23 of Set 3 | bestobe
# Processing Record 24 of Set 3 | balabac
# Processing Record 25 of Set 3 | caravelas
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of Set 3 | arraial do cabo
# Processing Record 27 of Set 3 | udachnyy
# Processing Record 28 of Set 3 | beringovskiy
# Processing Record 29 of Set 3 | chokurdakh
# Processing Record 30 of Set 3 | provideniya
# Processing Record 31 of Set 3 | barra dos coqueiros
# Processing Record 32 of Set 3 | bambous virieux
# Processing Record 33 of Set 3 | iqaluit
# Processing Record 34 of Set 3 | fredericton
# Processing Record 35 of Set 3 | swakopmund
# Processing Record 36 of Set 3 | nsoko
# Processing Record 37 of Set 3 | clyde river
# Processing Record 38 of Set 3 | mount isa
# Processing Record 39 of Set 3 | sandnessjoen
# Processing Record 40 of Set 3 | faanui
# Processing Record 41 of Set 3 | mareeba
# Processing Record 42 of Set 3 | mogadishu
# Processing Record 43 of Set 3 | karpathos
# City not found. Skipping...
# Processing Record 44 of Set 3 | watertown
# Processing Record 45 of Set 3 | ponta do sol
# Processing Record 46 of Set 3 | port blair
# Processing Record 47 of Set 3 | georgetown
# Processing Record 48 of Set 3 | norsup
# Processing Record 49 of Set 3 | acarau
# Processing Record 1 of Set 4 | victoria
# Processing Record 2 of Set 4 | marystown
# Processing Record 3 of Set 4 | nagaur
# Processing Record 4 of Set 4 | pevek
# Processing Record 5 of Set 4 | wilmington
# Processing Record 6 of Set 4 | port elizabeth
# Processing Record 7 of Set 4 | pangnirtung
# Processing Record 8 of Set 4 | koulikoro
# Processing Record 9 of Set 4 | tuatapere
# Processing Record 10 of Set 4 | wewak
# Processing Record 11 of Set 4 | tukums
# Processing Record 12 of Set 4 | galich
# City not found. Skipping...
# Processing Record 13 of Set 4 | teguldet
# Processing Record 14 of Set 4 | dikson
# Processing Record 15 of Set 4 | lodwar
# Processing Record 16 of Set 4 | apatity
# Processing Record 17 of Set 4 | tessalit
# Processing Record 18 of Set 4 | darnah
# Processing Record 19 of Set 4 | sola
# Processing Record 20 of Set 4 | kaitangata
# City not found. Skipping...
# Processing Record 21 of Set 4 | havre-saint-pierre
# Processing Record 22 of Set 4 | port-gentil
# Processing Record 23 of Set 4 | norman wells
# Processing Record 24 of Set 4 | barabai
# Processing Record 25 of Set 4 | santa luzia
# Processing Record 26 of Set 4 | bafoulabe
# Processing Record 27 of Set 4 | crab hill
# Processing Record 28 of Set 4 | savinka
# City not found. Skipping...
# Processing Record 29 of Set 4 | coahuayana
# Processing Record 30 of Set 4 | aklavik
# Processing Record 31 of Set 4 | salalah
# Processing Record 32 of Set 4 | novikovo
# Processing Record 33 of Set 4 | nelson bay
# Processing Record 34 of Set 4 | konosha
# Processing Record 35 of Set 4 | sarangani
# Processing Record 36 of Set 4 | kalamata
# Processing Record 37 of Set 4 | codrington
# City not found. Skipping...
# Processing Record 38 of Set 4 | oranjestad
# Processing Record 39 of Set 4 | souillac
# Processing Record 40 of Set 4 | humboldt
# City not found. Skipping...
# Processing Record 41 of Set 4 | tautira
# Processing Record 42 of Set 4 | wasilla
# Processing Record 43 of Set 4 | tchollire
# Processing Record 44 of Set 4 | tura
# Processing Record 45 of Set 4 | hasaki
# Processing Record 46 of Set 4 | abha
# Processing Record 47 of Set 4 | kutiyana
# Processing Record 48 of Set 4 | bafra
# Processing Record 49 of Set 4 | burnie
# Processing Record 1 of Set 5 | kendari
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 2 of Set 5 | garh maharaja
# Processing Record 3 of Set 5 | saldanha
# Processing Record 4 of Set 5 | beloha
# Processing Record 5 of Set 5 | mersing
# City not found. Skipping...
# Processing Record 6 of Set 5 | ribeira grande
# Processing Record 7 of Set 5 | deputatskiy
# Processing Record 8 of Set 5 | altamira
# Processing Record 9 of Set 5 | yulara
# Processing Record 10 of Set 5 | kugulta
# Processing Record 11 of Set 5 | carnduff
# Processing Record 12 of Set 5 | bonavista
# Processing Record 13 of Set 5 | port macquarie
# Processing Record 14 of Set 5 | maniitsoq
# Processing Record 15 of Set 5 | taunggyi
# Processing Record 16 of Set 5 | pitimbu
# Processing Record 17 of Set 5 | flin flon
# Processing Record 18 of Set 5 | kieta
# Processing Record 19 of Set 5 | sorland
# Processing Record 20 of Set 5 | zhuhai
# Processing Record 21 of Set 5 | vao
# Processing Record 22 of Set 5 | sangar
# Processing Record 23 of Set 5 | tiarei
# Processing Record 24 of Set 5 | soyo
# Processing Record 25 of Set 5 | mahebourg
# Processing Record 26 of Set 5 | tabou
# Processing Record 27 of Set 5 | pokhara
# Processing Record 28 of Set 5 | chicama
# Processing Record 29 of Set 5 | dingle
# Processing Record 30 of Set 5 | tutoia
# Processing Record 31 of Set 5 | custoias
# City not found. Skipping...
# Processing Record 32 of Set 5 | kushmurun
# Processing Record 33 of Set 5 | urumqi
# Processing Record 34 of Set 5 | aksarayskiy
# Processing Record 35 of Set 5 | storebo
# Processing Record 36 of Set 5 | luderitz
# Processing Record 37 of Set 5 | olga
# Processing Record 38 of Set 5 | soure
# Processing Record 39 of Set 5 | guane
# Processing Record 40 of Set 5 | christchurch
# Processing Record 41 of Set 5 | puerto el triunfo
# Processing Record 42 of Set 5 | angoche
# Processing Record 43 of Set 5 | birao
# City not found. Skipping...
# Processing Record 44 of Set 5 | fairbanks
# Processing Record 45 of Set 5 | castro
# Processing Record 46 of Set 5 | saint-philippe
# Processing Record 47 of Set 5 | rawatbhata
# Processing Record 48 of Set 5 | longyearbyen
# Processing Record 49 of Set 5 | itupiranga
# Processing Record 1 of Set 6 | bilibino
# Processing Record 2 of Set 6 | lohja
# Processing Record 3 of Set 6 | klaksvik
# Processing Record 4 of Set 6 | guerrero negro
# Processing Record 5 of Set 6 | waipawa
# Processing Record 6 of Set 6 | honiara
# Processing Record 7 of Set 6 | kavaratti
# Processing Record 8 of Set 6 | nabire
# Processing Record 9 of Set 6 | santiago
# Processing Record 10 of Set 6 | simao
# Processing Record 11 of Set 6 | namie
# Processing Record 12 of Set 6 | necochea
# Processing Record 13 of Set 6 | jiangyou
# Processing Record 14 of Set 6 | sheksna
# Processing Record 15 of Set 6 | balkanabat
# Processing Record 16 of Set 6 | fethiye
# Processing Record 17 of Set 6 | mys shmidta
# Processing Record 18 of Set 6 | vestmanna
# Processing Record 19 of Set 6 | gabu
# Processing Record 20 of Set 6 | beyneu
# Processing Record 21 of Set 6 | dayong
# Processing Record 22 of Set 6 | jiwani
# Processing Record 23 of Set 6 | kirakira
# Processing Record 24 of Set 6 | laplace
# Processing Record 25 of Set 6 | chuy
# Processing Record 26 of Set 6 | san jose
# Processing Record 27 of Set 6 | severo-kurilsk
# Processing Record 28 of Set 6 | gat
# Processing Record 29 of Set 6 | shu
# Processing Record 30 of Set 6 | xiashi
# Processing Record 31 of Set 6 | erzin
# Processing Record 32 of Set 6 | puerto baquerizo moreno
# City not found. Skipping...
# Processing Record 33 of Set 6 | malanje
# City not found. Skipping...
# Processing Record 34 of Set 6 | camargo
# Processing Record 35 of Set 6 | port keats
# Processing Record 36 of Set 6 | vanimo
# Processing Record 37 of Set 6 | raudeberg
# Processing Record 38 of Set 6 | shasta lake
# Processing Record 39 of Set 6 | lavrentiya
# Processing Record 40 of Set 6 | taoudenni
# Processing Record 41 of Set 6 | hede
# Processing Record 42 of Set 6 | kahului
# Processing Record 43 of Set 6 | saint-pierre
# Processing Record 44 of Set 6 | barentu
# Processing Record 45 of Set 6 | komsomolskiy
# Processing Record 46 of Set 6 | lufilufi
# Processing Record 47 of Set 6 | misratah
# City not found. Skipping...
# Processing Record 48 of Set 6 | coquimbo
# City not found. Skipping...
# Processing Record 49 of Set 6 | ayacucho
# Processing Record 1 of Set 7 | meadow lake
# Processing Record 2 of Set 7 | pahrump
# Processing Record 3 of Set 7 | nemuro
# Processing Record 4 of Set 7 | ajdabiya
# Processing Record 5 of Set 7 | tasiilaq
# Processing Record 6 of Set 7 | massaguet
# Processing Record 7 of Set 7 | volkach
# City not found. Skipping...
# Processing Record 8 of Set 7 | traiguen
# Processing Record 9 of Set 7 | oriximina
# Processing Record 10 of Set 7 | porto novo
# Processing Record 11 of Set 7 | carutapera
# Processing Record 12 of Set 7 | lompoc
# Processing Record 13 of Set 7 | eureka
# Processing Record 14 of Set 7 | hambantota
# Processing Record 15 of Set 7 | bakel
# Processing Record 16 of Set 7 | manuk mangkaw
# Processing Record 17 of Set 7 | poum
# Processing Record 18 of Set 7 | gornopravdinsk
# Processing Record 19 of Set 7 | ambunti
# Processing Record 20 of Set 7 | jiangmen
# Processing Record 21 of Set 7 | tarsus
# Processing Record 22 of Set 7 | rio grande city
# Processing Record 23 of Set 7 | cabo san lucas
# Processing Record 24 of Set 7 | sur
# Processing Record 25 of Set 7 | odweyne
# Processing Record 26 of Set 7 | thaton
# Processing Record 27 of Set 7 | namibe
# Processing Record 28 of Set 7 | inhambane
# Processing Record 29 of Set 7 | suez
# Processing Record 30 of Set 7 | makokou
# Processing Record 31 of Set 7 | whyalla
# Processing Record 32 of Set 7 | wagar
# Processing Record 33 of Set 7 | san quintin
# Processing Record 34 of Set 7 | pangody
# Processing Record 35 of Set 7 | san matias
# Processing Record 36 of Set 7 | nouakchott
# Processing Record 37 of Set 7 | askarovo
# Processing Record 38 of Set 7 | tucuman
# Processing Record 39 of Set 7 | luau
# Processing Record 40 of Set 7 | mezdra
# Processing Record 41 of Set 7 | kokoda
# Processing Record 42 of Set 7 | alofi
# Processing Record 43 of Set 7 | olafsvik
# Processing Record 44 of Set 7 | gashua
# Processing Record 45 of Set 7 | yibin
# Processing Record 46 of Set 7 | gubkinskiy
# Processing Record 47 of Set 7 | gushikawa
# Processing Record 48 of Set 7 | zharkent
# Processing Record 49 of Set 7 | palauig
# Processing Record 1 of Set 8 | tikhvin
# Processing Record 2 of Set 8 | priiskovyy
# Processing Record 3 of Set 8 | hovd
# Processing Record 4 of Set 8 | takestan
# Processing Record 5 of Set 8 | husavik
# Processing Record 6 of Set 8 | konstantinovka
# City not found. Skipping...
# Processing Record 7 of Set 8 | sao miguel dos campos
# Processing Record 8 of Set 8 | surt
# Processing Record 9 of Set 8 | sabzevar
# Processing Record 10 of Set 8 | nizhniy tsasuchey
# Processing Record 11 of Set 8 | portland
# Processing Record 12 of Set 8 | chapais
# Processing Record 13 of Set 8 | makakilo city
# Processing Record 14 of Set 8 | vardo
# Processing Record 15 of Set 8 | pombia
# Processing Record 16 of Set 8 | ascension
# Processing Record 17 of Set 8 | pryozerne
# Processing Record 18 of Set 8 | camana
# Processing Record 19 of Set 8 | mount gambier
# Processing Record 20 of Set 8 | ust-ishim
# Processing Record 21 of Set 8 | jiaohe
# Processing Record 22 of Set 8 | zemio
# Processing Record 23 of Set 8 | sabang
# Processing Record 24 of Set 8 | cagli
# Processing Record 25 of Set 8 | tutayev
# Processing Record 26 of Set 8 | khani
# Processing Record 27 of Set 8 | funehiki
# Processing Record 28 of Set 8 | hirara
# Processing Record 29 of Set 8 | gistel
# Processing Record 30 of Set 8 | mecca
# Processing Record 31 of Set 8 | klyuchi
# Processing Record 32 of Set 8 | isangel
# City not found. Skipping...
# Processing Record 33 of Set 8 | ponte de sor
# Processing Record 34 of Set 8 | strezhevoy
# Processing Record 35 of Set 8 | tanout
# Processing Record 36 of Set 8 | neiafu
# Processing Record 37 of Set 8 | fortuna
# Processing Record 38 of Set 8 | skibbereen
# Processing Record 39 of Set 8 | gweta
# Processing Record 40 of Set 8 | zhigansk
# Processing Record 41 of Set 8 | kamennomostskiy
# Processing Record 42 of Set 8 | sakakah
# Processing Record 43 of Set 8 | wonthaggi
# City not found. Skipping...
# Processing Record 44 of Set 8 | cabedelo
# Processing Record 45 of Set 8 | jibuti
# Processing Record 46 of Set 8 | dunedin
# Processing Record 47 of Set 8 | talavera de la reina
# Processing Record 48 of Set 8 | solnechnyy
# City not found. Skipping...
# Processing Record 49 of Set 8 | shetpe
# Processing Record 1 of Set 9 | swords
# Processing Record 2 of Set 9 | tombouctou
# Processing Record 3 of Set 9 | mantua
# Processing Record 4 of Set 9 | waitara
# Processing Record 5 of Set 9 | puerto escondido
# Processing Record 6 of Set 9 | luangwa
# Processing Record 7 of Set 9 | nurota
# Processing Record 8 of Set 9 | brigham city
# Processing Record 9 of Set 9 | abnub
# Processing Record 10 of Set 9 | roseburg
# Processing Record 11 of Set 9 | ballina
# Processing Record 12 of Set 9 | sexsmith
# Processing Record 13 of Set 9 | ferme-neuve
# Processing Record 14 of Set 9 | lorengau
# Processing Record 15 of Set 9 | ndele
# City not found. Skipping...
# Processing Record 16 of Set 9 | latung
# Processing Record 17 of Set 9 | broome
# Processing Record 18 of Set 9 | kovdor
# Processing Record 19 of Set 9 | kachiry
# City not found. Skipping...
# Processing Record 20 of Set 9 | rehoboth
# Processing Record 21 of Set 9 | baiao
# Processing Record 22 of Set 9 | srednekolymsk
# Processing Record 23 of Set 9 | tiznit
# Processing Record 24 of Set 9 | hami
# Processing Record 25 of Set 9 | anderson
# Processing Record 26 of Set 9 | oancea
# Processing Record 27 of Set 9 | kabompo
# Processing Record 28 of Set 9 | rawson
# Processing Record 29 of Set 9 | mitsamiouli
# Processing Record 30 of Set 9 | inuvik
# Processing Record 31 of Set 9 | vestmannaeyjar
# Processing Record 32 of Set 9 | lagoa
# Processing Record 33 of Set 9 | manyana
# Processing Record 34 of Set 9 | itarema
# Processing Record 35 of Set 9 | mandawar
# Processing Record 36 of Set 9 | ziro
# Processing Record 37 of Set 9 | half moon bay
# Processing Record 38 of Set 9 | akyab
# Processing Record 39 of Set 9 | ati
# Processing Record 40 of Set 9 | portovelo
# Processing Record 41 of Set 9 | nandu
# Processing Record 42 of Set 9 | bacong
# Processing Record 43 of Set 9 | sisimiut
# City not found. Skipping...
# Processing Record 44 of Set 9 | requena
# Processing Record 45 of Set 9 | kayerkan
# Processing Record 46 of Set 9 | goderich
# Processing Record 47 of Set 9 | himatnagar
# Processing Record 48 of Set 9 | yarada
# Processing Record 49 of Set 9 | majene
# Processing Record 1 of Set 10 | lubao
# Processing Record 2 of Set 10 | fereydun kenar
# Processing Record 3 of Set 10 | san vicente
# City not found. Skipping...
# Processing Record 4 of Set 10 | charters towers
# Processing Record 5 of Set 10 | porto velho
# Processing Record 6 of Set 10 | bengkulu
# Processing Record 7 of Set 10 | hofn
# Processing Record 8 of Set 10 | takaka
# Processing Record 9 of Set 10 | harper
# Processing Record 10 of Set 10 | mollendo
# City not found. Skipping...
# Processing Record 11 of Set 10 | vrangel
# Processing Record 12 of Set 10 | nantucket
# Processing Record 13 of Set 10 | sungairaya
# Processing Record 14 of Set 10 | kavieng
# Processing Record 15 of Set 10 | abancay
# City not found. Skipping...
# Processing Record 16 of Set 10 | hervey bay
# Processing Record 17 of Set 10 | allende
# Processing Record 18 of Set 10 | pakxan
# Processing Record 19 of Set 10 | belmonte
# Processing Record 20 of Set 10 | bozova
# Processing Record 21 of Set 10 | tongliao
# Processing Record 22 of Set 10 | bandarbeyla
# Processing Record 23 of Set 10 | lander
# Processing Record 24 of Set 10 | dalvik
# Processing Record 25 of Set 10 | burgeo
# Processing Record 26 of Set 10 | taksimo
# City not found. Skipping...
# Processing Record 27 of Set 10 | virginia beach
# Processing Record 28 of Set 10 | ornskoldsvik
# Processing Record 29 of Set 10 | altay
# Processing Record 30 of Set 10 | margate
# Processing Record 31 of Set 10 | oruro
# Processing Record 32 of Set 10 | upington
# Processing Record 33 of Set 10 | bintulu
# Processing Record 34 of Set 10 | hrebinka
# City not found. Skipping...
# Processing Record 35 of Set 10 | tazovskiy
# Processing Record 36 of Set 10 | ostersund
# Processing Record 37 of Set 10 | yumen
# Processing Record 38 of Set 10 | amuntai
# Processing Record 39 of Set 10 | pocone
# Processing Record 40 of Set 10 | turayf
# Processing Record 41 of Set 10 | visby
# Processing Record 42 of Set 10 | salinopolis
# Processing Record 43 of Set 10 | acajutla
# City not found. Skipping...
# Processing Record 44 of Set 10 | amazar
# Processing Record 45 of Set 10 | nouadhibou
# Processing Record 46 of Set 10 | kenai
# Processing Record 47 of Set 10 | zarubino
# Processing Record 48 of Set 10 | outram
# Processing Record 49 of Set 10 | joensuu
# Processing Record 1 of Set 11 | bull savanna
# Processing Record 2 of Set 11 | huarmey
# Processing Record 3 of Set 11 | kunming
# Processing Record 4 of Set 11 | madimba
# Processing Record 5 of Set 11 | tomatlan
# Processing Record 6 of Set 11 | naze
# Processing Record 7 of Set 11 | zaysan
# City not found. Skipping...
# Processing Record 8 of Set 11 | alice springs
# Processing Record 9 of Set 11 | camocim
# Processing Record 10 of Set 11 | khandyga
# Processing Record 11 of Set 11 | nador
# Processing Record 12 of Set 11 | bonthe
# Processing Record 13 of Set 11 | labuhan
# Processing Record 14 of Set 11 | griffith
# Processing Record 15 of Set 11 | kyabe
# City not found. Skipping...
# Processing Record 16 of Set 11 | vernon
# Processing Record 17 of Set 11 | mujiayingzi
# Processing Record 18 of Set 11 | mangrol
# Processing Record 19 of Set 11 | yatou
# Processing Record 20 of Set 11 | sidi ali
# Processing Record 21 of Set 11 | kaeo
# Processing Record 22 of Set 11 | tema
# Processing Record 23 of Set 11 | hue
# Processing Record 24 of Set 11 | sarangpur
# Processing Record 25 of Set 11 | northam
# Processing Record 26 of Set 11 | ancud
# Processing Record 27 of Set 11 | kouroussa
# Processing Record 28 of Set 11 | okhotsk
# Processing Record 29 of Set 11 | kanigoro
# Processing Record 30 of Set 11 | san martin
# Processing Record 31 of Set 11 | zhangjiakou
# Processing Record 32 of Set 11 | foz
# Processing Record 33 of Set 11 | laguna
# Processing Record 34 of Set 11 | sarapul
# Processing Record 35 of Set 11 | rio grande
# Processing Record 36 of Set 11 | namboongan
# Processing Record 37 of Set 11 | vilhena
# Processing Record 38 of Set 11 | ostrovnoy
# Processing Record 39 of Set 11 | sambava
# Processing Record 40 of Set 11 | faya
# Processing Record 41 of Set 11 | muros
# Processing Record 42 of Set 11 | ambilobe
# Processing Record 43 of Set 11 | whitefish
# Processing Record 44 of Set 11 | puerto leguizamo
# Processing Record 45 of Set 11 | college
# Processing Record 46 of Set 11 | khuzdar
# Processing Record 47 of Set 11 | narasannapeta
# Processing Record 48 of Set 11 | solginskiy
# Processing Record 49 of Set 11 | valparaiso
# Processing Record 1 of Set 12 | hammond
# Processing Record 2 of Set 12 | marawi
# Processing Record 3 of Set 12 | baihar
# Processing Record 4 of Set 12 | pisco
# Processing Record 5 of Set 12 | cap malheureux
# Processing Record 6 of Set 12 | ocos
# City not found. Skipping...
# Processing Record 7 of Set 12 | dhidhdhoo
# Processing Record 8 of Set 12 | verkhnyaya inta
# Processing Record 9 of Set 12 | paka
# City not found. Skipping...
# Processing Record 10 of Set 12 | arona
# Processing Record 11 of Set 12 | westport
# Processing Record 12 of Set 12 | sumbe
# City not found. Skipping...
# Processing Record 13 of Set 12 | riyadh
# Processing Record 14 of Set 12 | miranda de ebro
# Processing Record 15 of Set 12 | uige
# Processing Record 16 of Set 12 | asau
# Processing Record 17 of Set 12 | mulanje
# Processing Record 18 of Set 12 | sabya
# Processing Record 19 of Set 12 | kysyl-syr
# Processing Record 20 of Set 12 | honningsvag
# Processing Record 21 of Set 12 | kailua
# Processing Record 22 of Set 12 | lewiston
# Processing Record 23 of Set 12 | nangong
# Processing Record 24 of Set 12 | lata
# Processing Record 25 of Set 12 | luena
# Processing Record 26 of Set 12 | bedele
# Processing Record 27 of Set 12 | kharp
# Processing Record 28 of Set 12 | mabaruma
# Processing Record 29 of Set 12 | qaqortoq
# Processing Record 30 of Set 12 | ust-nera
# Processing Record 31 of Set 12 | tamandare
# Processing Record 32 of Set 12 | saint-augustin
# Processing Record 33 of Set 12 | inta
# City not found. Skipping...
# Processing Record 34 of Set 12 | sitka
# Processing Record 35 of Set 12 | porto belo
# Processing Record 36 of Set 12 | terralba
# City not found. Skipping...
# Processing Record 37 of Set 12 | formosa
# City not found. Skipping...
# Processing Record 38 of Set 12 | jaciara
# Processing Record 39 of Set 12 | kirando
# City not found. Skipping...
# Processing Record 40 of Set 12 | elko
# Processing Record 41 of Set 12 | fukue
# Processing Record 42 of Set 12 | banda aceh
# Processing Record 43 of Set 12 | rock hill
# Processing Record 44 of Set 12 | krasnooktyabrskiy
# Processing Record 45 of Set 12 | ippy
# Processing Record 46 of Set 12 | khasan
# Processing Record 47 of Set 12 | naruja
# Processing Record 48 of Set 12 | aberdeen
# Processing Record 49 of Set 12 | carcassonne
# Processing Record 1 of Set 13 | nagato
# Processing Record 2 of Set 13 | bristol
# Processing Record 3 of Set 13 | bur gabo
# Processing Record 4 of Set 13 | fukuma
# Processing Record 5 of Set 13 | krasnoselkup
# Processing Record 6 of Set 13 | kulunda
# Processing Record 7 of Set 13 | kamina
# Processing Record 8 of Set 13 | raton
# Processing Record 9 of Set 13 | mpophomeni
# Processing Record 10 of Set 13 | jalingo
# Processing Record 11 of Set 13 | bubaque
# Processing Record 12 of Set 13 | khunti
# Processing Record 13 of Set 13 | carahue
# Processing Record 14 of Set 13 | richards bay
# Processing Record 15 of Set 13 | manono
# Processing Record 16 of Set 13 | krasnoslobodsk
# Processing Record 17 of Set 13 | camacha
# Processing Record 18 of Set 13 | roebourne
# Processing Record 19 of Set 13 | makaleng
# Processing Record 20 of Set 13 | lingao
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 21 of Set 13 | santa rosa
# Processing Record 22 of Set 13 | meghraj
# Processing Record 23 of Set 13 | port lincoln
# Processing Record 24 of Set 13 | fort nelson
# Processing Record 25 of Set 13 | marquette
# City not found. Skipping...
# Processing Record 26 of Set 13 | namatanai
# Processing Record 27 of Set 13 | marsh harbour
# Processing Record 28 of Set 13 | cherlak
# Processing Record 29 of Set 13 | alexandroupoli
# Processing Record 30 of Set 13 | terme
# Processing Record 31 of Set 13 | pirovskoye
# Processing Record 32 of Set 13 | boende
# Processing Record 33 of Set 13 | umred
# Processing Record 34 of Set 13 | touros
# Processing Record 35 of Set 13 | yantal
# Processing Record 36 of Set 13 | smithers
# Processing Record 37 of Set 13 | takoradi
# Processing Record 38 of Set 13 | soe
# Processing Record 39 of Set 13 | mandalgovi
# Processing Record 40 of Set 13 | baherden
# Processing Record 41 of Set 13 | merauke
# Processing Record 42 of Set 13 | arlit
# Processing Record 43 of Set 13 | tyrma
# Processing Record 44 of Set 13 | xinpu
# Processing Record 45 of Set 13 | copiapo
# Processing Record 46 of Set 13 | narrabri
# Processing Record 47 of Set 13 | revda
# Processing Record 48 of Set 13 | saint-nazaire
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of Set 13 | biloxi
# Processing Record 1 of Set 14 | mahon
# Processing Record 2 of Set 14 | omboue
# Processing Record 3 of Set 14 | meybod
# Processing Record 4 of Set 14 | valkeakoski
# Processing Record 5 of Set 14 | cayenne
# Processing Record 6 of Set 14 | baykit
# Processing Record 7 of Set 14 | iwata
# Processing Record 8 of Set 14 | kemijarvi
# Processing Record 9 of Set 14 | esperance
# Processing Record 10 of Set 14 | hall
# Processing Record 11 of Set 14 | port hedland
# Processing Record 12 of Set 14 | hudson bay
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of Set 14 | belaya gora
# Processing Record 14 of Set 14 | kindu
# Processing Record 15 of Set 14 | nicoya
# Processing Record 16 of Set 14 | granada
# Processing Record 17 of Set 14 | hailar
# City not found. Skipping...
# Processing Record 18 of Set 14 | goba
# Processing Record 19 of Set 14 | san benito
# Processing Record 20 of Set 14 | nanakuli
# Processing Record 21 of Set 14 | maumere
# Processing Record 22 of Set 14 | tairua
# Processing Record 23 of Set 14 | dengzhou
# Processing Record 24 of Set 14 | buta
# Processing Record 25 of Set 14 | tilichiki
# Processing Record 26 of Set 14 | antalaha
# Processing Record 27 of Set 14 | pimenta bueno
# Processing Record 28 of Set 14 | hualmay
# Processing Record 29 of Set 14 | muyezerskiy
# Processing Record 30 of Set 14 | erenhot
# Processing Record 31 of Set 14 | plettenberg bay
# Processing Record 32 of Set 14 | mocuba
# Processing Record 33 of Set 14 | togur
# Processing Record 34 of Set 14 | grand bank
# Processing Record 35 of Set 14 | talnakh
# Processing Record 36 of Set 14 | washington
# Processing Record 37 of Set 14 | sinnamary
# Processing Record 38 of Set 14 | ust-kut
# Processing Record 39 of Set 14 | gobabis
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 40 of Set 14 | hatillo
# Processing Record 41 of Set 14 | ekibastuz
# Processing Record 42 of Set 14 | shingu
# Processing Record 43 of Set 14 | naberera
# Processing Record 44 of Set 14 | wawa
# Processing Record 45 of Set 14 | ribeirao
# Processing Record 46 of Set 14 | de-kastri
# Processing Record 47 of Set 14 | male
# Processing Record 48 of Set 14 | turukhansk
# Processing Record 49 of Set 14 | kilindoni
# Processing Record 1 of Set 15 | zarya
# Processing Record 2 of Set 15 | feldkirchen
# Processing Record 3 of Set 15 | puri
# Processing Record 4 of Set 15 | yerbogachen
# Processing Record 5 of Set 15 | luwuk
# Processing Record 6 of Set 15 | panguna
# Processing Record 7 of Set 15 | tarko-sale
# City not found. Skipping...
# Processing Record 8 of Set 15 | lucea
# City not found. Skipping...
# Processing Record 9 of Set 15 | kefamenanu
# Processing Record 10 of Set 15 | lakatoro
# Processing Record 11 of Set 15 | lourdes
# City not found. Skipping...
# Processing Record 12 of Set 15 | mmabatho
# City not found. Skipping...
# Processing Record 13 of Set 15 | chumikan
# Processing Record 14 of Set 15 | polazna
# Processing Record 15 of Set 15 | fallon
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
# Convert Raw Data to DataFrame
df=pd.DataFrame({"City name" : city_two,
"Cloudiness" : cloudiness,
"Dates" : dates,
"Humidities" :humidities,
"Lats" : lats,
'Lngs' :lngs,
'Max_temps' : max_temps,
"Wind_speeds" :wind_speeds})
df
# Out:
#           City name  Cloudiness       Dates  Humidities   Lats    Lngs  \
# 0          ust-nera          75  1594785335          44  64.57  143.20
# 1            albany          53  1594785128          74  42.60  -73.97
# 2       port alfred          54  1594785403          52  -7.03   29.76
# 3      punta arenas          12  1594785404          57   8.99  125.34
# 4             kharp         100  1594785376          94  66.80   65.81
# ..              ...         ...         ...         ...    ...     ...
# 668  cap malheureux          75  1594785633          87  49.27   -1.21
# 669           kiama         100  1594785578          85 -34.68  150.87
# 670          tiznit           0  1594785393          47  29.58   -9.50
# 671      banda aceh          69  1594785634          52  25.48   80.33
# 672     bronnoysund          97  1594785578          72  65.46   12.20
#
#      Max_temps  Wind_speeds
# 0        67.39         8.43
# 1        69.01         2.93
# 2        69.91         2.55
# 3        89.10         5.32
# 4        53.01         6.98
# ..         ...          ...
# 668      59.00        11.41
# 669      59.00         5.01
# 670      75.52         1.30
# 671      93.56         6.89
# 672      59.00         9.17
#
# [673 rows x 8 columns]

# %%
#pick only 500 cities 
weather_df=df.iloc[0:500,:]
weather_df
# Out:
#         City name  Cloudiness       Dates  Humidities   Lats    Lngs  \
# 0        ust-nera          75  1594785335          44  64.57  143.20
# 1          albany          53  1594785128          74  42.60  -73.97
# 2     port alfred          54  1594785403          52  -7.03   29.76
# 3    punta arenas          12  1594785404          57   8.99  125.34
# 4           kharp         100  1594785376          94  66.80   65.81
# ..            ...         ...         ...         ...    ...     ...
# 495   znamenskoye          37  1594785562          51  57.13   73.83
# 496     dongsheng           0  1594785562          32  39.82  109.98
# 497  port-cartier           5  1594785380          87  50.03  -66.87
# 498     san pedro          80  1594785620          74  13.30   -4.90
# 499          asfi           0  1594785396          88  32.30   -9.24
#
#      Max_temps  Wind_speeds
# 0        67.39         8.43
# 1        69.01         2.93
# 2        69.91         2.55
# 3        89.10         5.32
# 4        53.01         6.98
# ..         ...          ...
# 495      74.12         2.84
# 496      82.45         4.50
# 497      50.00         3.36
# 498      78.28        15.93
# 499      70.83        11.83
#
# [500 rows x 8 columns]

# %%
# Output File (CSV)
output_data_file = "Output/weather_df.csv"
# Export the city data into a .csv. Display the DataFrame
weather_df.to_csv(output_data_file )

# %%
# Plotting the Data

#  Temperature (F) vs. Latitude Plot

plt.scatter(weather_df["Lats"],weather_df["Max_temps"],edgecolors="black",facecolors="skyblue")
plt.title("City Max Temperature vs. Latitude(07/14/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("figures/fig1.png")
plt.show()
print(f'The plot is showing that the closer we get to the EQUATOR the tempratures increase!')
print('It is evident that there is a relationship between the two factors! ')
# Out:
# The plot is showing that the closer we get to the EQUATOR the tempratures increase!
# It is evident that there is a relationship between the two factors!

# %%
#  Humidity (%) vs. Latitude
plt.scatter(weather_df["Lats"],weather_df["Humidities"],edgecolors="black",facecolors="skyblue")
plt.title("City Humidities vs. Latitude(07/14/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("figures/fig2.png")
plt.show()
print(f'The plot is showing that most cities in the southern Hemisphere are humid whereas in the Northern Hemisphere humidity is variable')
# Out:
# The plot is showing that most cities in the southern Hemisphere are humid whereas in the Northern Hemisphere humidity is variable

# %%
#  Cloudiness (%) vs. Latitude
plt.scatter(weather_df["Lats"],weather_df["Cloudiness"],edgecolors="black",facecolors="skyblue")
plt.title("City Cloudiness vs. Latitude(07/14/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("figures/fig3.png")
plt.show()

print('There seems to be no relationship between the two factors! ')
# Out:
# There seems to be no relationship between the two factors!

# %%
#  Wind Speed (mph) vs. Latitude
plt.scatter(weather_df["Lats"],weather_df["Wind_speeds"],edgecolors="black",facecolors="skyblue")
plt.title("City Wind_speeds vs. Latitude(07/14/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind_speeds")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("figures/fig4.png")
plt.show()
print('There seems to be no relationship between the two factors! ')
# Out:
# There seems to be no relationship between the two factors!

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = weather_df.loc[pd.to_numeric(weather_df["Lats"]).astype(float) > 0, :]
southern_df = weather_df.loc[pd.to_numeric(weather_df["Lats"]).astype(float) < 0, :]

# %%
# create linear regression chart for Northern Hemisphere Temp vs. Latitude
x_values = pd.to_numeric(northern_df['Lats']).astype(float)
y_values = pd.to_numeric(northern_df['Max_temps']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,50),fontsize=15,color="red")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.xlabel('Lat')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.savefig("figures/fig5.png")
plt.show()
# Out:
# Regression line equation is: y = -0.48x + 88.88
# The r-squared is: -0.6820020254536061
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %%
# create linear regression chart for Southern Hemisphere Temp vs. Latitude
x_values = pd.to_numeric(southern_df['Lats']).astype(float)
y_values = pd.to_numeric(southern_df['Max_temps']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,80),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.savefig("figures/fig6.png")
plt.show()
# Out:
# Regression line equation is: y = 0.81x + 79.09
# The r-squared is: 0.7360301789518333
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %%
# create linear regression chart for Northern Hemisphere Humidity vs. Latitude
x_values = pd.to_numeric(northern_df['Lats']).astype(float)
y_values = pd.to_numeric(northern_df['Humidities']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,40),fontsize=15,color="red")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.savefig("figures/fig7.png")
plt.show()
# Out:
# Regression line equation is: y = -0.01x + 72.23
# The r-squared is: -0.006975816313722862
# The regression does not display much of a correlation between the data sets.

# %%
# create linear regression chart for Southern Hemisphere Humidity vs. Latitude
x_values = pd.to_numeric(southern_df['Lats']).astype(float)
y_values = pd.to_numeric(southern_df['Humidities']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.plot(x_values,regress_values,"r-")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.annotate(line_eq,(-55,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.savefig("figures/fig8.png")
plt.show()
# Out:
# Regression line equation is: y = -0.1x + 72.11
# The r-squared is: -0.07769681530505529
# The regression does not display much of a correlation between the data sets.

# %%
# create linear regression chart for Northern Hemisphere Cloudiness vs. Latitude
x_values = pd.to_numeric(northern_df['Lats']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.savefig("figures/fig9.png")
plt.show()
# Out:
# Regression line equation is: y = 0.01x + 53.62
# The r-squared is: 0.004912059320845523
# The regression does not display much of a correlation between the data sets.

# %%
# create linear regression chart for Southern Hemisphere Cloudiness vs. Latitude
x_values = pd.to_numeric(southern_df['Lats']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.plot(x_values,regress_values,"r-")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.annotate(line_eq,(-50,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.savefig("figures/fig10.png")
plt.show()
# Out:
# Regression line equation is: y = 0.28x + 50.7
# The r-squared is: 0.10112053313320268
# The regression does not display much of a correlation between the data sets.

# %%
# create linear regression chart for Northern Hemisphere Wind Speed vs. Latitude
x_values = pd.to_numeric(northern_df['Lats']).astype(float)
y_values = pd.to_numeric(northern_df['Wind_speeds']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.plot(x_values,regress_values,"r-")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.annotate(line_eq,(6,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.savefig("figures/fig11.png")
plt.show()
# Out:
# Regression line equation is: y = 0.0x + 7.21
# The r-squared is: 0.009142245356180039
# The regression does not display much of a correlation between the data sets.

# %%
# create linear regression chart for Southern Hemisphere Wind Speed vs. Latitude
x_values = pd.to_numeric(southern_df['Lats']).astype(float)
y_values = pd.to_numeric(southern_df['Wind_speeds']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.savefig("figures/fig12.png")
plt.show()
# Out:
# Regression line equation is: y = -0.03x + 6.23
# The r-squared is: -0.09568968415107382
# The regression does not display much of a correlation between the data sets.
